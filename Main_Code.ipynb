# %%
import requests
import re
import pandas as pd

# %%
#reading my api key file
with open('api.txt') as file:
    api_key = file.read().strip()
query = "\"Legumes and Legume Products\""

#creating a list from 5 pages of data from my API call
legus = []
for page in range(1,6):
    url = f'https://api.nal.usda.gov/fdc/v1/foods/list?api_key={api_key}&query={query}&pageNumber={page}'
    response = requests.get(url)
    legu_rows = response.json()
    legus.extend(legu_rows)

legusdf = pd.DataFrame(legus)

# %%
legusdf.head()
# Out:
#     fdcId                                        description   dataType  \
# 0  169893                               Bacon bits, meatless  SR Legacy
# 1  172439                                    Bacon, meatless  SR Legacy
# 2  173789  Beans, adzuki, mature seed, cooked, boiled, wi...  SR Legacy
# 3  173729     Beans, adzuki, mature seeds, canned, sweetened  SR Legacy
# 4  173728  Beans, adzuki, mature seeds, cooked, boiled, w...  SR Legacy
#
#   publicationDate ndbNumber                                      foodNutrients
# 0      2019-04-01     43212  [{'number': '319', 'name': 'Retinol', 'amount'...
# 1      2019-04-01     16104  [{'number': '431', 'name': 'Folic acid', 'amou...
# 2      2019-04-01     16302  [{'number': '268', 'name': 'Energy', 'amount':...
# 3      2019-04-01     16003  [{'number': '268', 'name': 'Energy', 'amount':...
# 4      2019-04-01     16002  [{'number': '268', 'name': 'Energy', 'amount':...
